# %% [markdown]
# # Working with Data - Computer Lab for Guest Lecture Julia Lane
#
# In this computer lab we will learn more more details and practice data work to enhance the content of the lecture presented by Julia Lane on responsible data use. We will address a research question, think about data and measurement errors, and manipulate data.
#
# OUTLINE:
# 1. Define a research question
# 2. Think about what data are available
# 3. Think about possible measurement errors
# 4. Think about the interpretation of your results
# 5. Inform your results by linking datasets

# %% [markdown]
# # 1. Define a reserach question
# Which Community Districts in NYC show the highest number of complaints?
#
# # 2. Think about what data are available
# Find suitable data by searching the CUSP Data Catalog https://datahub.cusp.nyu.edu/catalog. You can use Urban Profiler to investigate the Metadata associated with each dataset. Using this tool will help you to decide which attributes of the data you need to answer your question so you don't have to load the entire dataset.

# %%
import os
import pandas as pd
import numpy as np
import re
PUIdata = os.getenv('PUIDATA')

# %%
# check the env directory
os.getenv('DFDATA')
# Out:
# '/gws/open/NYCOpenData/nycopendata/data'

# %%
# locate file in CUSP
API = r'erm2-nwe9/1473456214/erm2-nwe9.csv'

# %%
# Load dataset
data1 = pd.read_csv(os.getenv('DFDATA')+'/'+ API, usecols=[1,5,9,21,23,24])
data1.head()
# Out:
#              Created Date      Complaint Type     Incident Address  \
# 0  02/02/2015 02:15:00 PM  Water Conservation       166 ATKINS AVE
# 1  02/02/2015 02:16:04 AM  Noise - Commercial        2117 3 AVENUE
# 2  02/02/2015 02:17:59 AM  Noise - Commercial        2117 3 AVENUE
# 3  02/02/2015 05:11:34 PM     Illegal Parking      18-08 21 AVENUE
# 4  02/02/2015 01:06:13 PM     Illegal Parking  1730 EAST 18 STREET
#
#                               Resolution Description       Community Board  \
# 0  The Department of Environmental Protection sch...  Unspecified BROOKLYN
# 1  The Police Department responded to the complai...          11 MANHATTAN
# 2  The Police Department responded to the complai...          11 MANHATTAN
# 3  The Police Department responded to the complai...             01 QUEENS
# 4  The Police Department responded to the complai...           15 BROOKLYN
#
#      Borough
# 0   BROOKLYN
# 1  MANHATTAN
# 2  MANHATTAN
# 3     QUEENS
# 4   BROOKLYN

# %% [markdown]
# # 3. Think about possible measurement errors
# Do you see any problems regarding possible measurement error? Think about who is represented in the data, ommissions, duplications, content error, missing data, etc.

# %%
# Check if all Boroughs and Community Districts are represented in the Data

# %%
  # sort data ascending by value
data1 = data1.sort_values(by='Community Board')

# %%
data1.Borough.unique()
# Out:
# array(['Unspecified', 'BRONX', 'BROOKLYN', 'MANHATTAN', 'QUEENS',
#        'STATEN ISLAND'], dtype=object)

# %%
data1['Community Board'].unique()
# Out:
# array(['0 Unspecified', '01 BRONX', '01 BROOKLYN', '01 MANHATTAN',
#        '01 QUEENS', '01 STATEN ISLAND', '02 BRONX', '02 BROOKLYN',
#        '02 MANHATTAN', '02 QUEENS', '02 STATEN ISLAND', '03 BRONX',
#        '03 BROOKLYN', '03 MANHATTAN', '03 QUEENS', '03 STATEN ISLAND',
#        '04 BRONX', '04 BROOKLYN', '04 MANHATTAN', '04 QUEENS', '05 BRONX',
#        '05 BROOKLYN', '05 MANHATTAN', '05 QUEENS', '06 BRONX',
#        '06 BROOKLYN', '06 MANHATTAN', '06 QUEENS', '07 BRONX',
#        '07 BROOKLYN', '07 MANHATTAN', '07 QUEENS', '08 BRONX',
#        '08 BROOKLYN', '08 MANHATTAN', '08 QUEENS', '09 BRONX',
#        '09 BROOKLYN', '09 MANHATTAN', '09 QUEENS', '10 BRONX',
#        '10 BROOKLYN', '10 MANHATTAN', '10 QUEENS', '11 BRONX',
#        '11 BROOKLYN', '11 MANHATTAN', '11 QUEENS', '12 BRONX',
#        '12 BROOKLYN', '12 MANHATTAN', '12 QUEENS', '13 BROOKLYN',
#        '13 QUEENS', '14 BROOKLYN', '14 QUEENS', '15 BROOKLYN',
#        '16 BROOKLYN', '17 BROOKLYN', '18 BROOKLYN', '26 BRONX', '27 BRONX',
#        '28 BRONX', '55 BROOKLYN', '56 BROOKLYN', '64 MANHATTAN',
#        '80 QUEENS', '81 QUEENS', '82 QUEENS', '83 QUEENS', '84 QUEENS',
#        '95 STATEN ISLAND', 'Unspecified BRONX', 'Unspecified BROOKLYN',
#        'Unspecified MANHATTAN', 'Unspecified QUEENS',
#        'Unspecified STATEN ISLAND'], dtype=object)

# %% [markdown]
# All Boroughs and Community Districts are represented

# %%
# How many unique values do we have? 
print ('Number of Boroughs: %s'%(len(data1['Borough'].unique())))
print ('Number of Community Districts: %s'%(len(data1['Community Board'].unique())))
# Out:
# Number of Boroughs: 6
# Number of Community Districts: 77

# %%
# Why do we have so many? Some of them are unspecified, missing. Some might be invalid entries. 
# We should have 59 Community Districts.

# %%
# Check for duplicates? Are these plausible?
print("Number of duplicated value: %s"%data1.duplicated().sum())
# Out:
# Number of duplicated value: 1205642

# %% [markdown]
# These duplicates are very likely to be plausible because I added 'created date' and 'incident address' to verify possible mistake when checking for duplicates. The possibility of a request that has the same address, created date and type of complaints is rather small. However, the number of missing values of 'Incident Address' is pretty high, we cannot rule out the possibility that duplicated values are identified because some values are missing, thus the duplicates might not be plausible and need double check by inviting other variables/columns from original dataset.

# %%
# What about missing values? Can you detect any patterns? 
  # First check general missing values
data1.count()
# Out:
# Created Date              13588781
# Complaint Type            13588781
# Incident Address          10499543
# Resolution Description    12996514
# Community Board           13588781
# Borough                   13588781
# dtype: int64

# %%
borough = data1.Borough.unique()

# %%
 # Check for missing values in each borough
for i in borough:
    print('Borough: %s '%i)
    print(data1[data1['Borough'] == i].count())
    print('\n')
# Out:
# Borough: BROOKLYN
# Created Date              3841933
# Complaint Type            3841933
# Incident Address          3101933
# Resolution Description    3675126
# Community Board           3841933
# Borough                   3841933
# dtype: int64
#
#
# Borough: MANHATTAN
# Created Date              2613583
# Complaint Type            2613583
# Incident Address          1973919
# Resolution Description    2487255
# Community Board           2613583
# Borough                   2613583
# dtype: int64
#
#
# Borough: QUEENS
# Created Date              2934521
# Complaint Type            2934521
# Incident Address          2186308
# Resolution Description    2787105
# Community Board           2934521
# Borough                   2934521
# dtype: int64
#
#
# Borough: STATEN ISLAND
# Created Date              639634
# Complaint Type            639634
# Incident Address          460144
# Resolution Description    607607
# Community Board           639634
# Borough                   639634
# dtype: int64
#
#
# Borough: Unspecified
# Created Date              1243390
# Complaint Type            1243390
# Incident Address           843046
# Resolution Description    1218601
# Community Board           1243390
# Borough                   1243390
# dtype: int64
#
#
# Borough: BRONX
# Created Date              2315720
# Complaint Type            2315720
# Incident Address          1934193
# Resolution Description    2220820
# Community Board           2315720
# Borough                   2315720
# dtype: int64

# %% [markdown]
# Each borough has missing values in 'Incident Address' and 'Resolution Description' parts. If we drop duplicated values before analyzing, the pattern will be similar

# %%
# Data Editing: Is it possible to replace missing values? Is it possible to use Complaint Type 
# to fill missings in Resolution Descriptor?
data2 = data1[data1.duplicated() == False]

# %%
CT_replace = data2['Complaint Type'][data2['Resolution Description'].isnull() == True]

# %%
data2.fillna({'Resolution Description': CT_replace})
# Out:
#                     Created Date                  Complaint Type  \
# 0         02/02/2015 02:15:00 PM              Water Conservation
# 1         02/02/2015 02:16:04 AM              Noise - Commercial
# 2         02/02/2015 02:17:59 AM              Noise - Commercial
# 3         02/02/2015 05:11:34 PM                 Illegal Parking
# 4         02/02/2015 01:06:13 PM                 Illegal Parking
# 5         02/02/2015 04:43:29 PM                 Illegal Parking
# 6         02/02/2015 11:17:34 AM                 Illegal Parking
# 7         02/02/2015 05:12:00 PM                           Sewer
# 8         02/02/2015 09:12:38 PM                 Illegal Parking
# 9         02/02/2015 10:06:09 AM                 Illegal Parking
# 10        02/02/2015 08:16:19 AM                 Illegal Parking
# 11        02/02/2015 07:48:27 AM                 Illegal Parking
# 12        02/02/2015 07:57:00 AM                    Water System
# 13        02/02/2015 09:20:07 PM             Noise - Residential
# 14        02/02/2015 06:34:02 PM             Noise - Residential
# 15        02/02/2015 06:22:38 PM             Noise - Residential
# 16        02/02/2015 01:58:01 PM          DOF Literature Request
# 17        02/02/2015 01:37:00 PM                           Sewer
# 18        02/02/2015 12:47:00 PM                           Sewer
# 19        02/02/2015 11:37:00 AM                           Sewer
# 20        02/02/2015 11:01:00 AM                           Sewer
# 21        02/02/2015 10:02:00 AM                           Sewer
# 22        02/02/2015 09:59:00 AM                           Sewer
# 23        02/02/2015 09:40:00 AM                           Sewer
# 24        02/02/2015 09:15:39 AM                 Illegal Parking
# 25        02/02/2015 02:35:00 PM                           Sewer
# 26        02/02/2015 09:38:00 AM                           Sewer
# 27        02/02/2015 06:58:00 AM                           Sewer
# 28        02/02/2015 06:52:00 AM                           Sewer
# 29        02/02/2015 12:00:00 AM                          Rodent
# ...                          ...                             ...
# 13588751  02/02/2015 07:32:00 AM            Sanitation Condition
# 13588752  02/02/2015 01:24:42 PM      DOF Property - Owner Issue
# 13588753  02/02/2015 09:43:00 AM        Traffic Signal Condition
# 13588754  02/02/2015 09:42:00 AM        Traffic Signal Condition
# 13588755  02/02/2015 06:59:00 AM        Traffic Signal Condition
# 13588756  02/02/2015 11:13:33 AM      DOF Property - Owner Issue
# 13588757  02/02/2015 02:32:48 PM  DOF Property - Reduction Issue
# 13588758  02/02/2015 03:43:00 PM        Traffic Signal Condition
# 13588759  02/02/2015 08:35:00 AM        Traffic Signal Condition
# 13588760  02/02/2015 09:26:18 AM  DOF Property - Reduction Issue
# 13588761  02/02/2015 01:05:00 PM        Traffic Signal Condition
# 13588762  02/02/2015 03:31:00 PM        Traffic Signal Condition
# 13588763  02/02/2015 03:56:02 PM                    Animal Abuse
# 13588764  02/02/2015 06:59:08 PM                    Damaged Tree
# 13588765  02/02/2015 02:02:00 PM                     Air Quality
# 13588766  02/02/2015 02:41:00 PM                           Sewer
# 13588767  02/02/2015 04:02:00 PM                           Sewer
# 13588768  02/02/2015 01:22:00 AM        Traffic Signal Condition
# 13588769  02/02/2015 04:09:45 PM          DOF Literature Request
# 13588770  02/02/2015 11:16:00 AM                           Sewer
# 13588771  02/02/2015 12:00:00 AM                        PLUMBING
# 13588772  02/02/2015 10:35:00 AM          Street Light Condition
# 13588773  02/02/2015 07:37:00 PM                           Sewer
# 13588774  02/02/2015 06:20:00 PM                           Sewer
# 13588775  02/02/2015 12:48:56 PM                 Illegal Parking
# 13588776  02/02/2015 12:38:19 PM                 Illegal Parking
# 13588777  02/02/2015 09:42:00 AM                           Sewer
# 13588778  02/02/2015 09:19:00 AM                           Sewer
# 13588779  02/02/2015 11:27:00 AM              Water Conservation
# 13588780  02/02/2015 12:11:23 PM          DOF Literature Request
#
#               Incident Address  \
# 0               166 ATKINS AVE
# 1                2117 3 AVENUE
# 2                2117 3 AVENUE
# 3              18-08 21 AVENUE
# 4          1730 EAST 18 STREET
# 5           305 EAST 46 STREET
# 6               13 DAVIS COURT
# 7                     164 9 ST
# 8                          NaN
# 9         75 MACDONOUGH STREET
# 10        22 SAINT JAMES PLACE
# 11             2 BRIDGE STREET
# 12         96-08 ROOSEVELT AVE
# 13         1730 EAST 18 STREET
# 14           2344 BRAGG STREET
# 15         2588 SEVENTH AVENUE
# 16                         NaN
# 17               324 HALSEY ST
# 18            153 SHARROTT AVE
# 19             20 CATHERINE ST
# 20                         NaN
# 21                         NaN
# 22             117 JOHNSON AVE
# 23               1132 E 108 ST
# 24                         NaN
# 25            560 RIVERSIDE DR
# 26               138-18 59 AVE
# 27                         NaN
# 28                         NaN
# 29          338 MADISON STREET
# ...                        ...
# 13588751                   NaN
# 13588752                   NaN
# 13588753                   NaN
# 13588754                   NaN
# 13588755                   NaN
# 13588756                   NaN
# 13588757                   NaN
# 13588758                   NaN
# 13588759                   NaN
# 13588760                   NaN
# 13588761                   NaN
# 13588762                   NaN
# 13588763                   NaN
# 13588764                   NaN
# 13588765              30 74 ST
# 13588766                   NaN
# 13588767       470 MIDLAND AVE
# 13588768                   NaN
# 13588769                   NaN
# 13588770                   NaN
# 13588771      101-11 86 AVENUE
# 13588772                   NaN
# 13588773          85-11 34 AVE
# 13588774        228 NORWAY AVE
# 13588775      326 STATE STREET
# 13588776                   NaN
# 13588777                   NaN
# 13588778                   NaN
# 13588779          153-02 76 RD
# 13588780                   NaN
#
#                                      Resolution Description  \
# 0         The Department of Environmental Protection sch...
# 1         The Police Department responded to the complai...
# 2         The Police Department responded to the complai...
# 3         The Police Department responded to the complai...
# 4         The Police Department responded to the complai...
# 5         The Police Department responded to the complai...
# 6         The Police Department responded to the complai...
# 7         The Department of Environmental Protection has...
# 8         The Police Department responded and upon arriv...
# 9         The Police Department responded to the complai...
# 10        The Police Department issued a summons in resp...
# 11        The Police Department responded to the complai...
# 12        The Department of Environmental Protection det...
# 13        The Police Department responded to the complai...
# 14        The Police Department responded to the complai...
# 15        The Police Department responded to the complai...
# 16        The literature will be emailed within 24 hours...
# 17        The Department of Environmental Protection ins...
# 18        The Department of Environment Protection inspe...
# 19        The Department of Environmental Protection ins...
# 20        The Department of Environmental Protection ins...
# 21        The Department of Environment Protection inspe...
# 22        The Department of Environment Protection inspe...
# 23        The Department of Environmental Protection has...
# 24        The Police Department responded to the complai...
# 25        The Department of Environment Protection inspe...
# 26        The Department of Environmental Protection has...
# 27        The Department of Environmental Protection inv...
# 28        The Department of Environmental Protection inv...
# 29        The Department of Health and Mental Hygiene wi...
# ...                                                     ...
# 13588751    The Department of Sanitation removed the items.
# 13588752                                         See notes.
# 13588753  Service Request status for this request is ava...
# 13588754  Service Request status for this request is ava...
# 13588755  Service Request status for this request is ava...
# 13588756                                         See notes.
# 13588757                                         See notes.
# 13588758  Service Request status for this request is ava...
# 13588759  Service Request status for this request is ava...
# 13588760                                         See notes.
# 13588761  Service Request status for this request is ava...
# 13588762  Service Request status for this request is ava...
# 13588763  The Police Department responded to the complai...
# 13588764  The Department of Parks and Recreation inspect...
# 13588765  The Department of Environmental Protection det...
# 13588766  The Department of Environmental Protection has...
# 13588767  The Department of Environmental Protection ins...
# 13588768  Service Request status for this request is ava...
# 13588769  The literature has been mailed. If it has not ...
# 13588770  The Department of Environmental Protection inv...
# 13588771  The Department of Housing Preservation and Dev...
# 13588772  Service Request status for this request is ava...
# 13588773  The Department of Environmental Protection inv...
# 13588774  The Department of Environmental Protection inv...
# 13588775  The Police Department responded and upon arriv...
# 13588776  The Police Department responded and upon arriv...
# 13588777  The Department of Environmental Protection inv...
# 13588778  The Department of Environment Protection inspe...
# 13588779  The Department of Environmental Protection inv...
# 13588780  The literature has been mailed. If it has not ...
#
#                     Community Board        Borough
# 0              Unspecified BROOKLYN       BROOKLYN
# 1                      11 MANHATTAN      MANHATTAN
# 2                      11 MANHATTAN      MANHATTAN
# 3                         01 QUEENS         QUEENS
# 4                       15 BROOKLYN       BROOKLYN
# 5                      06 MANHATTAN      MANHATTAN
# 6                  01 STATEN ISLAND  STATEN ISLAND
# 7              Unspecified BROOKLYN       BROOKLYN
# 8                         11 QUEENS         QUEENS
# 9                       03 BROOKLYN       BROOKLYN
# 10                     03 MANHATTAN      MANHATTAN
# 11                     01 MANHATTAN      MANHATTAN
# 12               Unspecified QUEENS         QUEENS
# 13                      15 BROOKLYN       BROOKLYN
# 14                      15 BROOKLYN       BROOKLYN
# 15                     10 MANHATTAN      MANHATTAN
# 16                    0 Unspecified    Unspecified
# 17             Unspecified BROOKLYN       BROOKLYN
# 18        Unspecified STATEN ISLAND  STATEN ISLAND
# 19            Unspecified MANHATTAN      MANHATTAN
# 20               Unspecified QUEENS         QUEENS
# 21               Unspecified QUEENS         QUEENS
# 22        Unspecified STATEN ISLAND  STATEN ISLAND
# 23             Unspecified BROOKLYN       BROOKLYN
# 24                 01 STATEN ISLAND  STATEN ISLAND
# 25            Unspecified MANHATTAN      MANHATTAN
# 26               Unspecified QUEENS         QUEENS
# 27             Unspecified BROOKLYN       BROOKLYN
# 28             Unspecified BROOKLYN       BROOKLYN
# 29                      03 BROOKLYN       BROOKLYN
# ...                             ...            ...
# 13588751                  07 QUEENS         QUEENS
# 13588752           01 STATEN ISLAND  STATEN ISLAND
# 13588753                  03 QUEENS         QUEENS
# 13588754                  06 QUEENS         QUEENS
# 13588755                  09 QUEENS         QUEENS
# 13588756                  07 QUEENS         QUEENS
# 13588757                10 BROOKLYN       BROOKLYN
# 13588758       Unspecified BROOKLYN       BROOKLYN
# 13588759                14 BROOKLYN       BROOKLYN
# 13588760                   10 BRONX          BRONX
# 13588761           01 STATEN ISLAND  STATEN ISLAND
# 13588762                01 BROOKLYN       BROOKLYN
# 13588763               12 MANHATTAN      MANHATTAN
# 13588764                   09 BRONX          BRONX
# 13588765       Unspecified BROOKLYN       BROOKLYN
# 13588766      Unspecified MANHATTAN      MANHATTAN
# 13588767  Unspecified STATEN ISLAND  STATEN ISLAND
# 13588768      Unspecified MANHATTAN      MANHATTAN
# 13588769              0 Unspecified    Unspecified
# 13588770      Unspecified MANHATTAN      MANHATTAN
# 13588771                  09 QUEENS         QUEENS
# 13588772          Unspecified BRONX          BRONX
# 13588773         Unspecified QUEENS         QUEENS
# 13588774  Unspecified STATEN ISLAND  STATEN ISLAND
# 13588775                02 BROOKLYN       BROOKLYN
# 13588776                  06 QUEENS         QUEENS
# 13588777         Unspecified QUEENS         QUEENS
# 13588778         Unspecified QUEENS         QUEENS
# 13588779         Unspecified QUEENS         QUEENS
# 13588780              0 Unspecified    Unspecified
#
# [12383139 rows x 6 columns]

# %%
# Generate marker for unplausible Community Districts
# How do these districts look like? 
district = data2['Community Board']
data2['Community Index'] = district.str.extract('(\d+)', expand=True)
data2.head()
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#              Created Date      Complaint Type     Incident Address  \
# 0  02/02/2015 02:15:00 PM  Water Conservation       166 ATKINS AVE
# 1  02/02/2015 02:16:04 AM  Noise - Commercial        2117 3 AVENUE
# 2  02/02/2015 02:17:59 AM  Noise - Commercial        2117 3 AVENUE
# 3  02/02/2015 05:11:34 PM     Illegal Parking      18-08 21 AVENUE
# 4  02/02/2015 01:06:13 PM     Illegal Parking  1730 EAST 18 STREET
#
#                               Resolution Description       Community Board  \
# 0  The Department of Environmental Protection sch...  Unspecified BROOKLYN
# 1  The Police Department responded to the complai...          11 MANHATTAN
# 2  The Police Department responded to the complai...          11 MANHATTAN
# 3  The Police Department responded to the complai...             01 QUEENS
# 4  The Police Department responded to the complai...           15 BROOKLYN
#
#      Borough Community Index
# 0   BROOKLYN             NaN
# 1  MANHATTAN              11
# 2  MANHATTAN              11
# 3     QUEENS              01
# 4   BROOKLYN              15

# %% [markdown]
# according to NYC COmmunity Portal https://www1.nyc.gov/site/planning/community/community-portal.page, the number of community district in each borough is:
# - Brooklyn: 18
# - Manhattan: 12
# - Bronx: 12
# - Statan Island: 3
# - Queens: 14

# %%
# Drop the marked districts
brooklyn =(data2['Community Index'] > 0) & (data2['Community Index'] < 19) & (data2['Borough'] == 'BROOKLYN')
manhattan =(data2['Community Index'] > 0) & (data2['Community Index'] < 13) & (data2['Borough'] == 'MANHATTAN')
bronx =(data2['Community Index'] > 0) & (data2['Community Index'] < 13) & (data2['Borough'] == 'BRONX')
statanisland =(data2['Community Index'] > 0) & (data2['Community Index'] < 4) & (data2['Borough'] == 'STATAN ISLAND')
queens =(data2['Community Index'] > 0) & (data2['Community Index'] < 15) & (data2['Borough'] == 'QUEENS')

# %%
communitydistrict = brooklyn | manhattan | bronx | statanisland | queens

# %%
data4 = data2[communitydistrict]
data4.head()
# Out:
#              Created Date      Complaint Type     Incident Address  \
# 1  02/02/2015 02:16:04 AM  Noise - Commercial        2117 3 AVENUE
# 2  02/02/2015 02:17:59 AM  Noise - Commercial        2117 3 AVENUE
# 3  02/02/2015 05:11:34 PM     Illegal Parking      18-08 21 AVENUE
# 4  02/02/2015 01:06:13 PM     Illegal Parking  1730 EAST 18 STREET
# 5  02/02/2015 04:43:29 PM     Illegal Parking   305 EAST 46 STREET
#
#                               Resolution Description Community Board  \
# 1  The Police Department responded to the complai...    11 MANHATTAN
# 2  The Police Department responded to the complai...    11 MANHATTAN
# 3  The Police Department responded to the complai...       01 QUEENS
# 4  The Police Department responded to the complai...     15 BROOKLYN
# 5  The Police Department responded to the complai...    06 MANHATTAN
#
#      Borough  Community Index
# 1  MANHATTAN             11.0
# 2  MANHATTAN             11.0
# 3     QUEENS              1.0
# 4   BROOKLYN             15.0
# 5  MANHATTAN              6.0

# %%
# Produce your result: Generate an indicator which ranks the Community District by complaint numbers 
# on the Community district level
 # count number of complaints
data5 = data4.groupby('Community Board').count()
data5.head()
# Out:
#                  Created Date  Complaint Type  Incident Address  \
# Community Board
# 01 BRONX                94587           94587             81052
# 01 BROOKLYN            230413          230413            181862
# 01 MANHATTAN            89717           89717             56504
# 01 QUEENS              216566          216566            168597
# 02 BRONX                72168           72168             61010
#
#                  Resolution Description  Borough  Community Index
# Community Board
# 01 BRONX                          90073    94587            94587
# 01 BROOKLYN                      218015   230413           230413
# 01 MANHATTAN                      83595    89717            89717
# 01 QUEENS                        205134   216566           216566
# 02 BRONX                          68456    72168            72168

# %%
data5.reset_index(inplace=True)
data5.drop(['Created Date', 'Incident Address','Resolution Description', 'Borough','Community Index'], 
           axis=1, inplace=True)
data5['Rank'] = data5['Community Board'].rank(ascending=False)
data5.head()
# Out:
#   Community Board  Complaint Type  Rank
# 0        01 BRONX           94587  56.0
# 1     01 BROOKLYN          230413  55.0
# 2    01 MANHATTAN           89717  54.0
# 3       01 QUEENS          216566  53.0
# 4        02 BRONX           72168  52.0

# %%
# Safe reduced data frame (Community District level)
data5.sort(columns='Rank').head()
# Out:
# /opt/rh/anaconda/root/envs/PUI2016_Python2/lib/python2.7/site-packages/ipykernel/__main__.py:2: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   from ipykernel import kernelapp as app
#    Community Board  Complaint Type  Rank
# 55     18 BROOKLYN          193135   1.0
# 54     17 BROOKLYN          223214   2.0
# 53     16 BROOKLYN          103416   3.0
# 52     15 BROOKLYN          173899   4.0
# 51       14 QUEENS          115551   5.0

# %% [markdown]
# # 4. Think about the interpretation of your results?
# What do you have to keep in mind when interpreting your results? Are they generable? Does the way the data is collected influence your results? To better inform city agancies it might be good to explore in more detail the underlying dempgraphics/infrastructure of a Community District becasue this might influence 311 calls. You can do this by merging external data on the Community District level to your analysis data.

# %%
# Population by Community District
df_pop = pd.read_csv(PUIdata + "/Final_Demographics.csv")
df_pop.head()
# Out:
#       FIPS cd_id  Total Population  Population Density (per sq. mile)  \
# 0  3603701  BX08            106737                        31229.95006
# 1  3603702  BX12            134644                        19966.67839
# 2  3603703  BX10            121209                        12913.81703
# 3  3603704  BX11            135839                        35677.95453
# 4  3603705  BX03            172247                        39405.79222
#
#    % Total Population: Male  % Total Population: 18 to 24 Years  \
# 0                     46.65                               10.73
# 1                     46.35                               11.35
# 2                     45.20                                8.62
# 3                     50.09                                8.10
# 4                     44.72                               14.24
#
#    % Total Population: 25 to 34 Years  % Total Population: 35 to 44 Years  \
# 0                               15.04                               11.32
# 1                               14.29                               12.57
# 2                               13.74                               12.78
# 3                               17.43                               14.09
# 4                               14.89                               12.38
#
#    % Population 5 Years And Over: Speak Only English  \
# 0                                              46.80
# 1                                              73.09
# 2                                              61.79
# 3                                              43.22
# 4                                              36.82
#
#    % Population 5 Years And Over: Spanish or Spanish Creole  \
# 0                                              39.24
# 1                                              18.19
# 2                                              26.43
# 3                                              36.45
# 4                                              54.24
#
#                                                                                 ...                                                                                \
# 0                                                                               ...
# 1                                                                               ...
# 2                                                                               ...
# 3                                                                               ...
# 4                                                                               ...
#
#    Employed Civilian Population 16 Years And Over: Production, transportation, and material moving  occupations: Production occupations  \
# 0                                                665
# 1                                               1156
# 2                                                941
# 3                                               2189
# 4                                               1437
#
#    Employed Civilian Population 16 Years And Over: Production, transportation, and material moving  occupations: Transportation and material moving occupations  \
# 0                                               1518
# 1                                               4174
# 2                                               3433
# 3                                               5592
# 4                                               5436
#
#    % Employed Civilian Population 16 Years And Over: Management, professional, and related occupations  \
# 0                                              42.66
# 1                                              29.57
# 2                                              36.20
# 3                                              30.06
# 4                                              16.80
#
#    % Employed Civilian Population 16 Years And Over: Service occupations  \
# 0                                              28.95
# 1                                              33.98
# 2                                              22.85
# 3                                              27.86
# 4                                              41.00
#
#    % Employed Civilian Population 16 Years And Over: Sales and office occupations  \
# 0                                              20.89
# 1                                              20.40
# 2                                              25.09
# 3                                              22.24
# 4                                              22.29
#
#    % Employed Civilian Population 16 Years And Over: Farming, fishing, and forestry occupations  \
# 0                                               0.24
# 1                                               0.00
# 2                                               0.00
# 3                                               0.00
# 4                                               0.03
#
#    % Employed Civilian Population 16 Years And Over: Construction, extraction, and maintenance  occupations  \
# 0                                               2.65
# 1                                               7.08
# 2                                               7.68
# 3                                               7.03
# 4                                               8.45
#
#    % Employed Civilian Population 16 Years And Over: Production, transportation, and material moving  occupations  \
# 0                                               4.60
# 1                                               8.97
# 2                                               8.18
# 3                                              12.81
# 4                                              11.43
#
#    % Employed Civilian Population 16 Years And Over: Production, transportation, and material moving  occupations: Production occupations  \
# 0                                               1.40
# 1                                               1.95
# 2                                               1.76
# 3                                               3.60
# 4                                               2.39
#
#    % Employed Civilian Population 16 Years And Over: Production, transportation, and material moving  occupations: Transportation and material moving occupations
# 0                                               3.20
# 1                                               7.02
# 2                                               6.42
# 3                                               9.20
# 4                                               9.04
#
# [5 rows x 158 columns]

# %%
# Check variables in file
len(df_pop.columns)
# Out:
# 158

# %%
# How many community districts are in file? 
len(df_pop.cd_id.unique())
# Out:
# 59

# %%
# Manipulate data to get some information on demographics by Community District. 
# Think about who might be more likely to call 311
# Save data frame
df_pop_2 = df_pop[['cd_id', 'Population Density (per sq. mile)']]
df_pop_2 = df_pop_2.sort_values(by='Population Density (per sq. mile)')
df_pop_2.head()
# Out:
#    cd_id  Population Density (per sq. mile)
# 25  SI02                        6371.997113
# 24  SI03                        6968.306388
# 58  QN14                        9541.923526
# 49  QN13                        9812.563966
# 26  SI01                       12537.604960

# %%
# Infrastructure by Community District
df_infr = pd.read_csv(PUIdata + "/ACS_Computer_Use_and_Internet_2014_1Year_Estimate.csv")
df_infr.head()
# Out:
#       FIPS Geographic Identifier  \
# 0  3603701        79500US3603701
# 1  3603702        79500US3603702
# 2  3603703        79500US3603703
# 3  3603704        79500US3603704
# 4  3603705        79500US3603705
#
#                                      Qualifying Name  Households  \
# 0  NYC-Bronx Community District 8--Riverdale, New...       42035
# 1  NYC-Bronx Community District 12--Wakefield, Ne...       44830
# 2  NYC-Bronx Community District 10--Co-op City, N...       47050
# 3  NYC-Bronx Community District 11--Pelham Parkwa...       44922
# 4  NYC-Bronx Community District 3 & 6--Belmont, N...       57556
#
#    Households: With An Internet Subscription  Households: Dial-Up Alone  \
# 0                                      31795                        444
# 1                                      32243                        178
# 2                                      32729                        158
# 3                                      32003                        141
# 4                                      35503                         88
#
#    Households: Dsl  Households: With Mobile Broadband  \
# 0             2813                                946
# 1              849                                405
# 2             1863                                398
# 3             1478                                474
# 4             1297                                651
#
#    Households: Without Mobile Broadband  Households: Cable Modem  \
# 0                                  1867                    19178
# 1                                   444                    18653
# 2                                  1465                    20044
# 3                                  1004                    17917
# 4                                   646                    15847
#
#             ...             Households: Mobile Broadband Alone or With Dialup  \
# 0           ...                                                          2168
# 1           ...                                                           928
# 2           ...                                                           639
# 3           ...                                                          1001
# 4           ...                                                          1385
#
#    Households: Internet Access Without A Subscription  \
# 0                                               2119
# 1                                               1891
# 2                                               2882
# 3                                               2722
# 4                                               3312
#
#    Households: No Internet Access  \
# 0                            8121
# 1                           10696
# 2                           11439
# 3                           10197
# 4                           18741
#
#    % Households: With An Internet Subscription  Households.1  \
# 0                                        75.64         42035
# 1                                        71.92         44830
# 2                                        69.56         47050
# 3                                        71.24         44922
# 4                                        61.68         57556
#
#    Households: Has A Computer  \
# 0                       35048
# 1                       36700
# 2                       38700
# 3                       37237
# 4                       42576
#
#    Households: With Dial-Up Internet Subscription Alone  \
# 0                                                404
# 1                                                178
# 2                                                158
# 3                                                122
# 4                                                 88
#
#    Households: With A Broadband Internet Subscription  \
# 0                                              30943
# 1                                              31435
# 2                                              32333
# 3                                              31278
# 4                                              33408
#
#    Households: Without An Internet Subscription  Households: No Computer
# 0                                          3701                     6987
# 1                                          5087                     8130
# 2                                          6209                     8350
# 3                                          5837                     7685
# 4                                          9080                    14980
#
# [5 rows x 31 columns]

# %%
# Check variables in file
len(df_infr.columns)
# Out:
# 31

# %%
# How many community districts are in file? 
len(df_infr['Qualifying Name'].unique())
# Out:
# 55

# %%
# Manipulate data to get some information on internet/broadband useage by Community District
# Aggregate the mobile subscription data
df_infr.columns
# Out:
# Index([u'FIPS', u'Geographic Identifier', u'Qualifying Name', u'Households',
#        u'Households: With An Internet Subscription',
#        u'Households: Dial-Up Alone', u'Households: Dsl',
#        u'Households: With Mobile Broadband',
#        u'Households: Without Mobile Broadband', u'Households: Cable Modem',
#        u'Households: With Mobile Broadband.1',
#        u'Households: Without Mobile Broadband.1', u'Households: Fiber-Optic',
#        u'Households: With Mobile Broadband.2',
#        u'Households: Without Mobile Broadband.2',
#        u'Households: Satellite Internet Service',
#        u'Households: With Mobile Broadband.3',
#        u'Households: Without Mobile Broadband.3',
#        u'Households: Two or More Fixed Broadband Types, or Other',
#        u'Households: With Mobile Broadband.4',
#        u'Households: Without Mobile Broadband.4',
#        u'Households: Mobile Broadband Alone or With Dialup',
#        u'Households: Internet Access Without A Subscription',
#        u'Households: No Internet Access',
#        u'% Households: With An Internet Subscription', u'Households.1',
#        u'Households: Has A Computer',
#        u'Households: With Dial-Up Internet Subscription Alone',
#        u'Households: With A Broadband Internet Subscription',
#        u'Households: Without An Internet Subscription',
#        u'Households: No Computer'],
#       dtype='object')

# %%
# Aggregate internet type by high and low connections

# %%
# Save data frame

# %% [markdown]
# # 5. Inform your results by linking datasets
# Now you want to link the three data frames to produce summary statistics for Community Districts which show a high number of complaints vs. Community Districts which show a lower number of complaints. Please keep in mind that the identifiers used for the linkage (Community Dostrict IDs) should be recored the same way. Use regular expressions to harmonize the identifiers if possible. The identifiers should look like BK01, BK02, etc.
# https://docs.python.org/2/library/re.html

# %%
# Harmonize identifier of dataframe 1

# %% [markdown]
# harmonize community districts into identifiers like BK01, BK02 similar to 'cd_id' in df_pop_2.

# %%
# Harmonize identifier of dataframe 2

# %%
# Harmonize identifier of dataframe 3

# %%
# Link the 3 dataframes
Linkedpd = pd.merge(data5, df_pop_2, on='cd_id', how = 'outer')
Linkedpd = pd.merge(Linkedpd, df_infr, on='cd_id', how = 'outer')

# %%
# Are the demographics and infrastructure different in Community Districts that show more complaints than others?
